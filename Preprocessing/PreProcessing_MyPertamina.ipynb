# %%
import pandas as pd
import numpy as np

TWEET_DATA = pd.read_csv("mypertamina_label.csv", encoding = "ISO-8859-1")
TWEET_DATA['Teksbersih'].str.encode('ascii', 'ignore')
TWEET_DATA.head()
# Out:
#                                           Teksbersih  \
# 0  alun al kahfi malam moga allah rahmat jalan ba...
# 1                          beli bensin dah pake apk
# 2  warga kota tasikmalaya pilih beli bbm spbu dae...
# 3       tuku bbm subsidi sing kudu nganggo aplikasi
# 4  daftar subsidi tp ga save data kendara ny mu e...
#
#                                            translate klasifikasi
# 0  alun al kahfi night moga allah rahmat jalan ba...    negative
# 1                    buy gasoline already using  apk    negative
# 2  residents of the city of tasikmalaya choose bu...    negative
# 3    tuku bbm subsidized sing kudu nganggo the  appl    negative
# 4  list of subsidies but not saving data kendara ...    negative

# %%
 #------ Case Folding --------
# gunakan fungsi Series.str.lower() pada Pandas
TWEET_DATA['Teksbersih'] = TWEET_DATA['Teksbersih'].str.lower()


print('Case Folding Result : \n')
print(TWEET_DATA['Teksbersih'].head(5))
print('\n\n\n')
# Out:
# Case Folding Result :
#
# 0    alun al kahfi malam moga allah rahmat jalan ba...
# 1                            beli bensin dah pake apk
# 2    warga kota tasikmalaya pilih beli bbm spbu dae...
# 3         tuku bbm subsidi sing kudu nganggo aplikasi
# 4    daftar subsidi tp ga save data kendara ny mu e...
# Name: Teksbersih, dtype: object

# %%
import string
import re #regex library
import nltk
nltk.download('punkt')
# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# ------ Tokenizing ---------

def remove_tweet_special(text):
    # remove tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")

TWEET_DATA['Teksbersih'] = TWEET_DATA['Teksbersih'].apply(remove_tweet_special)

#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

TWEET_DATA['Teksbersih'] = TWEET_DATA['Teksbersih'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

TWEET_DATA['Teksbersih'] = TWEET_DATA['Teksbersih'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

TWEET_DATA['Teksbersih'] = TWEET_DATA['Teksbersih'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

TWEET_DATA['Teksbersih'] = TWEET_DATA['Teksbersih'].apply(remove_whitespace_multiple)

# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

TWEET_DATA['Teksbersih'] = TWEET_DATA['Teksbersih'].apply(remove_singl_char)

# NLTK word rokenize
def word_tokenize_wrapper(text):
    return word_tokenize(text)

TWEET_DATA['tweet_tokens'] = TWEET_DATA['Teksbersih'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n')
print(TWEET_DATA['tweet_tokens'].head())
print('\n\n\n')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Tokenizing Result :
#
# 0    [alun, al, kahfi, malam, moga, allah, rahmat, ...
# 1                       [beli, bensin, dah, pake, apk]
# 2    [warga, kota, tasikmalaya, pilih, beli, bbm, s...
# 3    [tuku, bbm, subsidi, sing, kudu, nganggo, apli...
# 4    [daftar, subsidi, tp, ga, save, data, kendara,...
# Name: tweet_tokens, dtype: object

# %%
# NLTK calc frequency distribution
def freqDist_wrapper(text):
    return FreqDist(text)

TWEET_DATA['tweet_tokens_fdist'] = TWEET_DATA['tweet_tokens'].apply(freqDist_wrapper)

print('Frequency Tokens : \n')
print(TWEET_DATA['tweet_tokens_fdist'].head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(alun, 1), (al, 1), (kahfi, 1), (malam, 1), (...
# 1    [(beli, 1), (bensin, 1), (dah, 1), (pake, 1), ...
# 2    [(beli, 2), (bbm, 2), (warga, 1), (kota, 1), (...
# 3    [(tuku, 1), (bbm, 1), (subsidi, 1), (sing, 1),...
# 4    [(ga, 2), (daftar, 1), (subsidi, 1), (tp, 1), ...
# Name: tweet_tokens_fdist, dtype: object

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')
print(len(list_stopwords))

# ---------------------------- manualy add stopword  ------------------------------------
# append additional stopword
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo',
                       'kalo', 'amp', 'biar', 'bikin', 'bilang',
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih',
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya',
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't',
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah'])
len(list_stopwords)
# ----------------------- add stopword from txt file ------------------------------------
# read txt stopword using pandas
txt_stopword = pd.read_csv("stopwordbahasa.csv", names= ["stopwords"], header = None)

# convert stopword string to list & append additional stopword
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))
len(list_stopwords)
# ---------------------------------------------------------------------------------------

# convert list to dictionary
list_stopwords = set(list_stopwords)


#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

TWEET_DATA['tweet_tokens_WSW'] = TWEET_DATA['tweet_tokens'].apply(stopwords_removal)


print(TWEET_DATA['tweet_tokens_WSW'].head())
# Out:
# 758
# 0    [alun, al, kahfi, malam, moga, allah, rahmat, ...
# 1                       [beli, bensin, dah, pake, apk]
# 2    [warga, kota, tasikmalaya, pilih, beli, bbm, s...
# 3    [tuku, bbm, subsidi, sing, kudu, nganggo, apli...
# 4    [daftar, subsidi, tp, save, data, kendara, mu,...
# Name: tweet_tokens_WSW, dtype: object
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
normalizad_word = pd.read_csv("normalisasi.csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1]

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

TWEET_DATA['tweet_normalized'] = TWEET_DATA['tweet_tokens_WSW'].apply(normalized_term)

TWEET_DATA['tweet_normalized'].head(10)
# Out:
# 0    [alun, al, kahfi, malam, semoga, allah, rahmat...
# 1                      [beli, bensin, deh, pakai, apk]
# 2    [warga, kota, tasikmalaya, pilih, beli, bbm, s...
# 3    [tuku, bbm, subsidi, sing, harus, nganggo, apl...
# 4    [daftar, subsidi, tapi, save, data, kendara, m...
# 5    [solusi, efektif, tekan, beban, uang, negara, ...
# 6                                  [gin, melulu, dahh]
# 7    [syarat, beli, bahan, bakar, minyak, bbm, subs...
# 8    [antri, gara-gara, ternate, masuk, kota, ujico...
# 9    [beli, pertalite, solar, pakai, beli, tabung, ...
# Name: tweet_normalized, dtype: object

# %%
# import Sastrawi package
# !pip install Sastrawi
# !pip install swifter
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter
# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in TWEET_DATA['tweet_normalized']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '

print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])

print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

TWEET_DATA['tweet_tokens_stemmed'] = TWEET_DATA['tweet_normalized'].swifter.apply(get_stemmed_term)
print(TWEET_DATA['tweet_tokens_stemmed'])
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 5.1 MB/s
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting swifter
#   Downloading swifter-1.1.4.tar.gz (647 kB)
#      |████████████████████████████████| 647 kB 5.2 MB/s
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (1.3.5)
# Collecting psutil>=5.6.6
#   Downloading psutil-5.9.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (281 kB)
#      |████████████████████████████████| 281 kB 46.5 MB/s
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (2.12.0)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (4.64.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (7.7.0)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from swifter) (1.3.0)
# Requirement already satisfied: parso>0.4.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (0.8.3)
# Requirement already satisfied: bleach>=3.1.1 in /usr/local/lib/python3.7/dist-packages (from swifter) (5.0.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (1.15.0)
# Collecting partd>=0.3.10
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 76.3 MB/s
# Requirement already satisfied: toolz>=0.7.3 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.11.2)
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.21.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (1.1.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.4.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (3.6.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (4.10.1)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.5.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.3.5)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.8.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (1.0.18)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (57.4.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.6.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.8.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (4.10.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (2.15.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (4.3.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (4.1.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (4.11.4)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (5.7.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (21.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (3.8.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->swifter) (2022.1)
# Collecting locket
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.3.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.6.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.13.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.11.3)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (23.1.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.0.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.4)
# Building wheels for collected packages: swifter
#   Building wheel for swifter (setup.py) ... done
#   Created wheel for swifter: filename=swifter-1.1.4-py3-none-any.whl size=13932 sha256=abe9a1dd26eb996b1302763e57b6d7c173eb0793211648b5c4e3f1d66af73749
#   Stored in directory: /root/.cache/pip/wheels/e6/ca/b7/6b63fdb01fddb851b2b2b45c3812c6eec7a41e79e62ac99276
# Successfully built swifter
# Installing collected packages: locket, partd, fsspec, psutil, swifter
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
# Successfully installed fsspec-2022.5.0 locket-1.0.0 partd-1.2.0 psutil-5.9.1 swifter-1.1.4
# Streaming output truncated to the last 5000 lines.
# ok : ok
# bpa : bpa
# gmna : gmna
# mksain : mksain
# pkenya : pkenya
# boros : boros
# lurus : lurus
# siur : siur
# distributif : distributif
# paka : paka
# minus : minus
# ale : ale
# cec : cec
# sambel : sambel
# cabe : cabe
# idul : idul
# adha : adha
# daging : daging
# sapi : sapi
# buktipelanggaran : buktipelanggaran
# tahan : tahan
# jul : jul
# newsone : newsone
# cariberitaditvone : cariberitaditvone
# kripto : kripto
# gateio : gateio
# dailycryptonews : dailycryptonews
# bitcoinetf : bitcoinetf
# websitenya : websitenya
# maksyarakat : maksyarakat
# moderen : moderen
# su : su
# curahanhati : curahanhati
# bnyak : bnyak
# testimoni : testimoni
# btp : btp
# apl : apl
# diterapin : diterapin
# mlibatkan : mlibatkan
# rusuh : rusuh
# ptgs : ptgs
# perspektif : perspektif
# pedjabat : pedjabat
# gaksie : gaksie
# gampangin : gampangin
# maksay : maksay
# grabpools : grabpools
# shio : shio
# kerbau : kerbau
# batikpoker : batikpoker
# togelgrabpools : togelgrabpools
# sihhh : sihhh
# tega : tega
# liga : liga
# dibales : dibales
# damai : damai
# sahkan : sahkan
# hap : hap
# zaman : zaman
# londo : londo
# mengurus : urus
# mgg : mgg
# smp : smp
# teroris : teroris
# selesai : selesai
# direview : direview
# bobrok : bobrok
# nyak : nyak
# hujan : hujan
# ngadat : ngadat
# halim : halim
# siy : siy
# love : love
# sibuk : sibuk
# ngepusingin : ngepusingin
# dzulhijah : dzulhijah
# usul : usul
# beres : beres
# nge : nge
# himbau : himbau
# marak : marak
# klarifikasi : klarifikasi
# open : open
# kaum : kaum
# milenial : milenial
# uwa : uwa
# gedor : gedor
# beliau : beliau
# kerjannya : kerjannya
# serentak : serentak
# berkah : berkah
# dagang : dagang
# jnck : jnck
# masif : masif
# ikn : ikn
# lohh : lohh
# banya : banya
# imbau : imbau
# teliti : teliti
# menginput : menginput
# daftarr : daftarr
# lanjur : lanjur
# duluan : duluan
# suudzon : suudzon
# endingnya : endingnya
# membahas : bahas
# kate : kate
# mtr : mtr
# adu : adu
# nyali : nyali
# padang : padang
# tanah : tanah
# bagaima : bagaima
# janda : janda
# dorong : dorong
# lowbat : lowbat
# erti : erti
# diservernya : diservernya
# berkat : berkat
# urbanreaders : urbanreaders
# idcorner : idcorner
# daftarin : daftarin
# untu : untu
# akap : akap
# angkut : angkut
# jas : jas
# krukup : krukup
# taruh : taruh
# ujan : ujan
# huwiii : huwiii
# gausa : gausa
# nyebar : nyebar
# fear : fear
# cukong : cukong
# panen : panen
# usut : usut
# galon : galon
# kemudi : kemudi
# jujur : jujur
# gorilla : gorilla
# dehh : dehh
# mnggunakan : mnggunakan
# mnyusahkan : mnyusahkan
# rejim : rejim
# lucknut : lucknut
# kapan : kapan
# binasax : binasax
# mereka : mereka
# esemka : esemka
# car : car
# catika : catika
# prokontra : prokontra
# dilakuin : dilakuin
# sesuaiin : sesuaiin
# hall : hall
# bsrcode : bsrcode
# badan : badan
# legalisator : legalisator
# teknis : teknis
# tracking : tracking
# pil : pil
# kondisi : kondisi
# jaring : jaring
# keadaaan : keadaaan
# alc : alc
# tanang : tanang
# ngasi : ngasi
# unit : unit
# penggunany : penggunany
# mager : mager
# mantau : mantau
# ngeribetin : ngeribetin
# gofood : gofood
# ngojeknya : ngojeknya
# grabbike : grabbike
# disupirin : disupirin
# gocar : gocar
# belanja : belanja
# shopetoped : shopetoped
# ngutangnya : ngutangnya
# ci : ci
# dtks : dtks
# kemensos : kemensos
# oiya : oiya
# basmi : basmi
# benah : benah
# gamalu : gamalu
# jurus : jurus
# kons : kons
# seni : seni
# dar : dar
# bansos : bansos
# sakti : sakti
# moncer : moncer
# miris : miris
# riset : riset
# sblmnnya : sblmnnya
# nisa : nisa
# nolak : nolak
# dibkin : dibkin
# teteh : teteh
# cinambo : cinambo
# timbun : timbun
# printout : printout
# praktekin : praktekin
# lewat : lewat
# bilang : bilang
# nerapin : nerapin
# akan : akan
# seribet : seribet
# prfmnews : prfmnews
# sambal : sambal
# mr : mr
# crispy : crispy
# bawang : bawang
# tras : tras
# balado : balado
# rica : rica
# hijau : hijau
# thai : thai
# tag : tag
# lee : lee
# zii : zii
# jia : jia
# impi : impi
# heeseung : heeseung
# job : job
# how : how
# belielpiji : belielpiji
# kgpakaiaplikasi : kgpakaiaplikasi
# msih : msih
# gapake : gapake
# hri : hri
# cebong : cebong
# sialan : sial
# ayuk : ayuk
# prahara : prahara
# mertua : mertua
# menantu : menantu
# indra : indra
# bekti : bekti
# seleweng : seleweng
# granola : granola
# chocolate : chocolate
# vanilla : vanilla
# cokelat : cokelat
# langka : langka
# alih : alih
# janggal : janggal
# cece : cece
# semuaaa : semuaaa
# nyodorin : nyodorin
# both : both
# sbnarnya : sbnarnya
# garansi : garansi
# netflix : netflix
# sewa : sewa
# zoom : zoom
# coursehero : coursehero
# grammarly : grammarly
# scribd : scribd
# canva : canva
# quillbot : quillbot
# turnitin : turnitin
# hulu : hulu
# hbo : hbo
# amazon : amazon
# prime : prime
# picsart : picsart
# gold : gold
# nordvpn : nordvpn
# vypr : vypr
# skillshare : skillshare
# prifad : prifad
# tom : tom
# hiddleston : hiddleston
# miroh : miroh
# ribka : ribka
# viki : viki
# beritasampit : beritasampit
# cintakuh : cintakuh
# wibsite : wibsite
# lampu : lampu
# konsul : konsul
# clear : clear
# baheula : baheula
# ngaluarkeun : ngaluarkeun
# jiga : jiga
# padahalmah : padahalmah
# pungsikeun : pungsikeun
# ieu : ieu
# wowoy : wowoy
# undi : undi
# umroh : umroh
# thead : thead
# brosur : brosur
# tent : tent
# holder : holder
# akrilik : akrilik
# display : display
# sisi : sisi
# golkar : golkar
# cac : cac
# contek : contek
# umpat : umpat
# tulang : tulang
# trial : trial
# esok : esok
# sudan : sudan
# hampar : hampar
# langit : langit
# bertahta : bertahta
# angkasa : angkasa
# pijar : pijar
# tri : tri
# cepatsembuh : cepatsembuh
# halaman : halaman
# nightmare : nightmare
# taufikurachman : taufikurachman
# kart : kart
# kalimantan : kalimantan
# selatan : selatan
# sulawesi : sulawesi
# utara : utara
# manager : manager
# relation : relation
# csr : csr
# sumbagut : sumbagut
# konsume : konsume
# inforaka : inforaka
# penggu : penggu
# positif : positif
# bbmnya : bbmnya
# printoutqrcode : printoutqrcode
# cus : cus
# ditgl : ditgl
# ngecheat : ngecheat
# superjunior : superjunior
# cheat : cheat
# lunkaja : lunkaja
# payment : payment
# hola : hola
# takde : takde
# cicilan : cicil
# investasi : investasi
# saham : saham
# pluang : pluang
# halodoc : halodoc
# pedulikindungi : pedulikindungi
# nkre : nkre
# republik : republik
# endonesah : endonesah
# seperti : seperti
# wot : wot
# gawoh : gawoh
# adong : adong
# sajo : sajo
# bkin : bkin
# bagong : bagong
# demokrasisistemsampah : demokrasisistemsampah
# anjur : anjur
# pendaftaranya : pendaftaranya
# lesat : lesat
# sensasi : sensasi
# akselerasi : akselerasi
# ro : ro
# spbunya : spbunya
# derita : derita
# batre : batre
# ngedrop : ngedrop
# menek : menek
# pentahapan : pentahapan
# saudaralaki-laki : saudaralaki-laki
# aministrasi : aministrasi
# curhatan : curhatan
# wag : wag
# dibatesin : dibatesin
# vaksin : vaksin
# dng : dng
# aplikasiya : aplikasiya
# nyusul : nyusul
# include : include
# tentuin : tentuin
# fams : fams
# marketing : marketing
# objectivenya : objectivenya
# ups : ups
# indonesiamaju : indonesiamaju
# transfer : transfer
# puluha : puluha
# struk : struk
# rfid : rfid
# headline : headline
# rusak : rusak
# selagi : selagi
# rung : rung
# mobilitas : mobilitas
# dinas : dinas
# industri : industri
# cekdulumedcom : cekdulumedcom
# nelayan : nelayan
# manado : manado
# skeptisisme : skeptisisme
# nusantara : nusantara
# jl : jl
# kartini : kartini
# palu : palu
# telpon : telpon
# sebagaiberikut : sebagaiberikut
# hrsnya : hrsnya
# nopolnya : nopolnya
# quota : quota
# perban : perban
# luas : luas
# interface : interface
# regional : regional
# mars : mars
# ega : ega
# legowo : legowo
# pandanganjogja : pandanganjogja
# kumpar : kumpar
# plis : plis
# gantiin : gantiin
# hehebe : hehebe
# kemal : kemal
# palevi : palevi
# jamaah : jamaah
# stonks : stonks
# koruptif : koruptif
# hedon : hedon
# silitlah : silitlah
# menitsmartphone : menitsmartphone
# episode : episode
# kare : kare
# ketimbang : ketimbang
# onlen : onlen
# mass : mass
# adoption : adoption
# indonya : indonya
# ngeluh : ngeluh
# urgensi : urgensi
# simontok : simontok
# cnnindonesia : cnnindonesia
# sosmed : sosmed
# lindungin : lindungin
# bi : bi
# elok : elok
# mengkatagorikan : mengkatagorikan
# masyaraka : masyaraka
# patuh : patuh
# mengunakan : mengunakan
# omw : omw
# kilo : kilo
# hpkan : hpkan
# dinyicil : dinyicil
# hmm : hmm
# why : why
# newsmerahputih : newsmerahputih
# tanggap : tanggap
# jateng : jateng
# kerepot : kerepot
# michat : michat
# bukittinggi : bukittinggi
# kereunnn : kereunnn
# bersubsi : bersubsi
# jansen : jansen
# elite : elite
# meribetkan : meribetkan
# filter : filter
# kompresi : kompresi
# nentuin : nentuin
# tipe : tipe
# technology : technology
# ignition : ignition
# boost : boost
# formula : formula
# rubah : rubah
# taktis : taktis
# pinter : pinter
# fakuy : fakuy
# nafkah : nafkah
# seh : seh
# posisi : posisi
# ovo : ovo
# gopay : gopay
# alami : alami
# niatx : niatx
# nganter : nganter
# adik : adik
# jarum : jarum
# tkp : tkp
# tepatsasaran : tepatsasaran
# orangorang : orangorang
# kontra : kontra
# dompet : dompet
# newsrctiplus : newsrctiplus
# depa : depa
# bondong : bondong
# mgtplay : mgtplay
# cmo : cmo
# agen : agen
# iniinstagram : iniinstagram
# getwellsoonyuta : getwellsoonyuta
# depositpulsa : depositpulsa
# agenslotgacor : agenslotgacor
# togelonline : togelonline
# casinoonline : casinoonline
# bonusdeposit : bonusdeposit
# bonusslot : bonusslot
# judigacor : judigacor
# deposittermurah : deposittermurah
# ekonom : ekonom
# analisis : analisis
# http : http
# toll : toll
# alfamart : alfamart
# indomaret : indomaret
# aytalk : aytalk
# smartconsumer : smartconsumer
# bersikukuh : bersikukuh
# anggar : anggar
# bengkak : bengkak
# saking : saking
# mayan : mayan
# nyediain : nyediain
# rada : rada
# keder : keder
# yaqin : yaqin
# tsbt : tsbt
# supaya : supaya
# kan : kan
# linknya : linknya
# gesek : gesek
# raup : raup
# pria : pria
# sintang : sintang
# sisik : sisik
# trenggiling : trenggiling
# pontianak : pontianak
# teringgiling : teringgiling
# hewan : hewan
# binatang : binatang
# batuhankaracakaya : batuhankaracakaya
# sobattangerang : sobattangerang
# monggo : monggo
# beda : beda
# didownload : didownload
# safe : safe
# nti : nti
# mostupdate : mostupdate
# emil : emil
# rhiner : rhiner
# konfirmasi : konfirmasi
# sambung : sambung
# konsekuensi : konsekuensi
# norma : norma
# konflik : konflik
# pipinsopian : pipinsopian
# gun : gun
# sejarah : sejarah
# dasar : dasar
# agustus : agustus
# genjot : genjot
# bini : bini
# nye : nye
# amburadul : amburadul
# hancur : hancur
# kes : kes
# metoda : metoda
# kotoran : kotor
# layang : layang
# hlkompasiana : hlkompasiana
# nyenengin : nyenengin
# ngantor : ngantor
# manggung : manggung
# ngerawat : ngerawat
# kunjung : kunjung
# giwang : giwang
# kantor : kantor
# surakarta : surakarta
# patraniagarjbt : patraniagarjbt
# deg : deg
# ngalangin : ngalangin
# dipinggirin : dipinggirin
# nervous : nervous
# overall : overall
# vibesnya : vibesnya
# lok : lok
# tole : tole
# iskandar : iskandar
# depok : depok
# ontheway,sedangdijalan : ontheway sedangdijalan
# coco : coco
# patrang : patrang
# dewan : dewan
# plejing : plejing
# eksekutif : eksekutif
# core : core
# mohammad : mohammad
# faisal : faisal
# tida : tida
# teknolohi : teknolohi
# produk : produk
# sobatkom : sobatkom
# inisiatif : inisiatif
# wasap : wasap
# kelen : kelen
# alfian : alfian
# nasution : nasution
# segmentasi : segmentasi
# ketua : ketua
# ylki : ylki
# tulus : tulus
# abadi : abadi
# lite : lite
# ajhhh : ajhhh
# sumatera : sumatera
# stor : stor
# citer : citer
# kalong : kalong
# cit : cit
# rf : rf
# public : public
# kash : kash
# ecomerce : ecomerce
# gabung : gabung
# pmbayaran : pmbayaran
# administrasi : administrasi
# tempo : tempo
# getol : getol
# malas : malas
# kreatif : kreatif
# kaleee : kaleee
# klean : klean
# luarbiasa : luarbiasa
# modded : modded
# arm : arm
# entryurl : entryurl
# ningkatin : ningkatin
# skill : skill
# friendswithdex : friendswithdex
# durableenginee : durableenginee
# dieselhematbertenaga : dieselhematbertenaga
# uttuk : uttuk
# ruda : ruda
# digitalisasi : digitalisasi
# kemalpalevi : kemalpalevi
# hallo : hallo
# sedang : sedang
# bio : bio
# plot : plot
# twistnya : twistnya
# kelontong : kelontong
# spklu : spklu
# terpongkeng : terpongkeng
# netijen : netijen
# stuck : stuck
# temu : temu
# jodoh : jodoh
# chat : chat
# endonesia : endonesia
# prank : prank
# huahahahah : huahahahah
# mautahuurusanorang : mautahuurusanorang
# syampah : syampah
# thoughts : thoughts
# indihome : indihome
# appstore : appstore
# discan : discan
# mail : mail
# sieeeee : sieeeee
# hiks : hiks
# inovasi : inovasi
# redam : redam
# tertanda : tanda
# koplax : koplax
# gesit : gesit
# sikat : sikat
# centang : centang
# instruksi : instruksi
# maksimal : maksimal
# status : status
# bule : bule
# libur : libur
# buzzerp : buzzerp
# nasdempeduli : nasdempeduli
# kompor : kompor
# gituajakokribet : gituajakokribet
# nai : nai
# rak : rak
# asw : asw
# ndadak : ndadak
# pimpin : pimpin
# few : few
# years : years
# im : im
# casually : casually
# using : using
# but : but
# now : now
# have : have
# activating : activating
# at : at
# okay : okay
# probs : probs
# about : about
# not : not
# know : know
# sembilanbahanpokok : sembilanbahanpokok
# tutorialmempersulithidup : tutorialmempersulithidup
# gasak : gasak
# radarbanjarmasin : radarbanjarmasin
# aturansakarepmu : aturansakarepmu
# emal : emal
# sas : sas
# live : live
# streaming : streaming
# tethering : tethering
# jambu : jambu
# kristal : kristal
# biji : biji
# flyinghigh : flyinghigh
# kcame : kcame
# rusia : rusia
# time : time
# seventeen : seventeen
# doa : doa
# misi : misi
# mmbeli : mmbeli
# jangka : jangka
# kesiap : kesiap
# rakit : rakit
# benci : benci
# mel : mel
# ras : ras
# jelasin : jelasin
# pertanyaa : pertanyaa
# ngedownload : ngedownload
# hadap : hadap
# invasi : invasi
# publisherstory : publisherstory
# ahhh : ahhh
# copotmentridongok : copotmentridongok
# available : available
# basa : basa
# basi : basi
# crot : crot
# hogeeyyy : hogeeyyy
# calling : calling
# dimonitoring : dimonitoring
# etawa : etawa
# bubuk : bubuk
# cream : cream
# provit : provit
# krimer : krimer
# napas : napas
# asma : asma
# kolesterol : kolesterol
# tegur : tegur
# kriuk : kriuk
# kutuk : kutuk
# duli : duli
# wahh : wahh
# samping : samping
# setor : setor
# limit : limit
# lonjak : lonjak
# revisi : revisi
# jeblug : jeblug
# mainin : mainin
# tujuh : tujuh
# surat : surat
# sumbar : sumbar
# sumaid : sumaid
# mataindonesia : mataindonesia
# gaslpg : gaslpg
# htimu : htimu
# geopolitik : geopolitik
# global : global
# kpj : kpj
# men : men
# pasu : pasu
# mining : mining
# radio : radio
# diblow : diblow
# codenya : codenya
# minum : minum
# serbuk : serbuk
# aneka : aneka
# name : name
# kda : kda
# kawatir : kawatir
# reviewnya : reviewnya
# utas : utas
# ketriger : ketriger
# complain : complain
# appsnya : appsnya
# ngurangin : ngurangin
# halus : halus
# sumpah : sumpah
# spay : spay
# tix : tix
# id : id
# cinepolus : cinepolus
# bnr : bnr
# lpgmelon : lpgmelon
# ilegal : ilegal
# regis : regis
# spbuask : spbuask
# tmpat : tmpat
# rekom : rekom
# dmna : dmna
# fuel : fuel
# wkeoakeoa : wkeoakeoa
# relas : relas
# dompetdigital : dompetdigital
# uangtunai : uangtunai
# lampungpostid : lampungpostid
# mendi : mendi
# cibubur : cibubur
# merepotin : merepotin
# gederasa : gederasa
# javaland : javaland
# samsat : samsat
# match : match
# th : th
# kritisi : kritisi
# lembaga : lembaga
# kelompok : kelompok
# mamit : mamit
# runding : runding
# bas : bas
# mengakomodir : mengakomodir
# uninstal : uninstal
# ghensin : ghensin
# impact : impact
# sen : sen
# sellernya : sellernya
# jad : jad
# banten : banten
# sartono : sartono
# hutomo : hutomo
# cancel : cancel
# bareng : bareng
# nusabali : nusabali
# koordinat : koordinat
# hahahahaa : hahahahaa
# oalah : oalah
# yowis : yowis
# kui : kui
# apik : apik
# adewe : adewe
# lan : lan
# konco : konco
# ikut : ikut
# ros : ros
# cah : cah
# ngono : ngono
# may : may
# diatasnamakan : diatasnamakan
# only : only
# kayu : kayu
# hws : hws
# bhaikkkk : bhaikkkk
# bantal : bantal
# guling : guling
# kasur : kasur
# panas : panas
# sigit : sigit
# pengguba : pengguba
# dijadiin : dijadiin
# sarkas : sarkas
# cctv : cctv
# minta : minta
# mediasosial : mediasosial
# hilir : hilir
# konon : konon
# infomoga : infomoga
# abalnya : abalnya
# beritajakarta : beritajakarta
# spotify : spotify
# hayooo : hayooo
# permisi : permisi
# hobi : hobi
# mandatory : mandatory
# fieldnya : fieldnya
# gerak : gerak
# namatin : namatin
# butut : butut
# alokasi : alokasi
# pelat : pelat
# mabok : mabok
# tombol : tombol
# ngelempar : ngelempar
# event : event
# ngke : ngke
# outputnya : outputnya
# ngontrol : ngontrol
# modern : modern
# fotokopi : fotokopi
# kaji : kaji
# kapasitas : kapasitas
# wargi : wargi
# edisi : edisi
# perarturan : perarturan
# phk : phk
# karyawan : karyawan
# jajar : jajar
# direksi : direksi
# mengritik : mengritik
# ngumpulin : ngumpulin
# pegang : pegang
# tibalik : tibalik
# rekrut : rekrut
# biru : biru
# terkapar : kapar
# kgk : kgk
# gnakan : gnakan
# suhu : suhu
# tjd : tjd
# terllu : terllu
# perhatikan : perhati
# jang : jang
# nara : nara
# tampan : tampan
# mantan : mantan
# pacar : pacar
# thedefenders : thedefenders
# nampung : nampung
# massa : massa
# aga : aga
# trust : trust
# issue : issue
# seleksi : seleksi
# kamjar : kamjar
# drew : drew
# varu : varu
# bakaaln : bakaaln
# relate : relate
# fomo : fomo
# dwnload : dwnload
# smpe : smpe
# diwajibkn : diwajibkn
# cheater : cheater
# lhoo : lhoo
# shine : shine
# tenan : tenan
# lur : lur
# melakuka : melakuka
# pilot : pilot
# tumpang : tumpang
# riau : riau
# infopku : infopku
# pekanbaru : pekanbaru
# raih : raih
# tebar : tebar
# ributin : ributin
# karbitan : karbitan
# offense : offense
# konsep : konsep
# kupon : kupon
# srilanka : srilanka
# berkas : berkas
# nurut : nurut
# gusur : gusur
# disclaimer : disclaimer
# wan : wan
# abud : abud
# pollingelshinta : pollingelshinta
# ewkwk : ewkwk
# mahasiswa : mahasiswa
# demo : demo
# gen : gen
# millenial : millenial
# muda : muda
# tech : tech
# huhu : huhu
# question : question
# mark : mark
# serbaguna : serbaguna
# dibebasin : dibebasin
# pek : pek
# indonesiabanget : indonesiabanget
# donate : donate
# akh : akh
# yh : yh
# navigasi : navigasi
# ulun : ulun
# kalsel : kalsel
# wrapup : wrapup
# podcastindonesia : podcastindonesia
# wakil : wakil
# semalem : semalem
# mimpi : mimpi
# ramee : ramee
# gasuka : gasuka
# pressure : pressure
# life : life
# lelah : lelah
# workload : workload
# infosumbar : infosumbar
# pjs : pjs
# kebijkaan : kebijkaan
# hanya : hanya
# kbjakan : kbjakan
# kbijakan : kbijakan
# rok : rok
# kualitas : kualitas
# rep : rep
# definisi : definisi
# whole : whole
# peluang : peluang
# legal : legal
# medis : medis
# tandan : tandan
# buah : buah
# segar : segar
# kalimantantimur : kalimantantimur
# busuk : busuk
# buletinpagi : buletinpagi
# sofar : sofar
# bapuk : bapuk
# lets : lets
# asuransi : asuransi
# pras : pras
# detail : detail
# apkh : apkh
# jika : jika
# collab : collab
# gimana : gimana
# ning : ning
# rasah : rasah
# yukk : yukk
# aceh : aceh
# masakininews : masakininews
# andal : andal
# selalujadiandalan : selalujadiandalan
# dngan : dngan
# ktika : ktika
# mlakukan : mlakukan
# rat : rat
# he : he
# em : em
# nuklir : nuklir
# melakukn : melakukn
# dengan : dengan
# jugah : jugah
# mlkukn : mlkukn
# spek : spek
# tel : tel
# beroktan : beroktan
# portalyogoya : portalyogoya
# ngk : ngk
# uttk : uttk
# hannya : hannya
# kulak : kulak
# nggk : nggk
# ntuk : ntuk
# mumpuni : mumpuni
# metrohariini : metrohariini
# gojek : gojek
# smntra : smntra
# perfectioninperformance : perfectioninperformance
# karat : karat
# tanpa : tanpa
# sus : sus
# pantang : pantang
# wasalam : wasalam
# bsatuan : bsatuan
# klutik : klutik
# dongoooooo : dongoooooo
# dgan : dgan
# ngedumel : ngedumel
# anjirr : anjirr
# srius : srius
# andro : andro
# nokia : nokia
# laptop : laptop
# pc : pc
# srg : srg
# dw : dw
# mlu : mlu
# bela : bela
# bajerin : bajerin
# ibukku : ibukku
# tulalit : tulalit
# ibuk : ibuk
# yld : yld
# buletininewspagi : buletininewspagi
# form : form
# woalah : woalah
# tur : tur
# udu : udu
# bien : bien
# meh : meh
# jarene : jarene
# gek : gek
# kerep : kerep
# luwih : luwih
# hahahahaah : hahahahaah
# kolot : kolot
# mngkin : mngkin
# pinjem : pinjem
# pinjeman : pinjeman
# dmksd : dmksd
# cilok : cilok
# keluarin : keluarin
# bgimana : bgimana
# antipasi : antipasi
# ngising : ngising
# nguyuh : nguyuh
# ngebayangin : ngebayangin
# laran : laran
# okezoners : okezoners
# nyo : nyo
# anjlokin : anjlokin
# karni : karni
# ilyas : ilyas
# club : club
# jurubicara : jurubicara
# gana : gana
# otoritas : otoritas
# simpul : simpul
# televisi : televisi
# stiker : stiker
# dear : dear
# diinstall : diinstall
# jatah : jatah
# riweuh : riweuh
# le : le
# tingkatin : tingkatin
# masyara : masyara
# haluan : haluan
# vivo : vivo
# pipis : pipis
# dadak : dadak
# wakanda : wakanda
# kapal : kapal
# ferizi : ferizi
# cilik : cilik
# kompetibel : kompetibel
# aktivitas : aktivitas
# yakali : yakali
# ongkoskirim : ongkoskirim
# moodbooster : moodbooster
# unggul : unggul
# judgemental : judgemental
# mempersiapkan : siap
# kurir : kurir
# shop : shop
# cashbac : cashbac
# yayasan : yayasan
# bbc : bbc
# juara : juara
# kecoh : kecoh
# minat : minat
# moodboster : moodboster
# api : api
# jend : jend
# wakandastan : wakandastan
# land : land
# genting : genting
# reward : reward
# kalas : kalas
# microsoft : microsoft
# office : office
# dikadalin : dikadalin
# tny : tny
# nominal : nominal
# disney : disney
# hotstar : hotstar
# viu : viu
# wetv : wetv
# vidio : vidio
# iqiyi : iqiyi
# ajaa : ajaa
# spp : spp
# sekolah : sekolah
# appk : appk
# hoaks : hoaks
# solo : solo
# prinsip : prinsip
# pasuk : pasuk
# wiliayah : wiliayah
# apresiasi : apresiasi
# setia : setia
# mengunak : mengunak
# voksupdate : voksupdate
# voksradiojogja : voksradiojogja
# memb : memb
# kacaaauuuu : kacaaauuuu
# internetnya : internetnya
# neraka : neraka
# sinemaelektronik : sinemaelektronik
# faedah : faedah
# linkedin : linkedin
# nyetir : nyetir
# semangkin : semangkin
# rkytnya : rkytnya
# diant : diant
# sipalingmarvel : sipalingmarvel
# get : get
# wel : wel
# ngeinstal : ngeinstal
# gae : gae
# moto : moto
# gp : gp
# caradapatpertalite : caradapatpertalite
# menyesu : menyesu
# pendapate : pendapate
# liquefied : liquefied
# petroleum : petroleum
# krna : krna
# papa : papa
# benernya : benernya
# sling : sling
# bag : bag
# selempang : selempang
# muat : muat
# tokopedia : tokopedia
# fashion : fashion
# dingin : dingin
# morningg : morningg
# reng : reng
# dinding : dinding
# inimagelangku : inimagelangku
# gerai : gerai
# asia : asia
# ima : ima
# future : future
# damn : damn
# yaah : yaah
# gih : gih
# secara : cara
# tem : tem
# target : target
# minimalisir : minimalisir
# gelut : gelut
# ricuh : ricuh
# disaranin : disaranin
# narik : narik
# yha : yha
# kha : kha
# selubung : selubung
# anjiiir : anjiiir
# byuemen : byuemen
# puluh : puluh
# mencak : mencak
# jare : jare
# dolan : dolan
# dikon : dikon
# gov : gov
# checkin : checkin
# agreement : agreement
# syapa : syapa
# lowong : lowong
# anjerrrr : anjerrrr
# nafas : nafas
# onlime : onlime
# ofline : ofline
# pasti : pasti
# muk : muk
# mniez : mniez
# impeachment : impeachment
# konstitusi : konstitusi
# mk : mk
# majelispermusyawaratanrakyat : majelispermusyawaratanrakyat
# sektor : sektor
# bersih : bersih
# giiran : giiran
# hina : hina
# delik : delik
# serap : serap
# aspirasi : aspirasi
# ajarin : ajarin
# berisik : berisik
# daaah : daaah
# unistal : unistal
# peg : peg
# polisi : polisi
# knderaan : knderaan
# salim : salim
# lai : lai
# mampus : mampus
# mi : mi
# ski : ski
# liput : liput
# sctv : sctv
# avanza : avanza
# penghisa : penghisa
# energijatimbalinus : energijatimbalinus
# energiuntukmaju : energiuntukmaju
# patraniagajatimbalinus : patraniagajatimbalinus
# selingkuh : selingkuh
# well : well
# soon : soon
# yuta : yuta
# log : log
# tetiba : tetiba
# nyeletuk : nyeletuk
# desa : desa
# koentji : koentji
# lindungipeduli : lindungipeduli
# sgr : sgr
# banned : banned
# dripada : dripada
# motorr : motorr
# generate : generate
# jabarjuara : jabarjuara
# jabarjuaralahirbatin : jabarjuaralahirbatin
# ridwankamil : ridwankamil
# cobain : cobain
# kewat : kewat
# skip : skip
# merger : merger
# sdhlah : sdhlah
# monokrom : monokrom
# gimane : gimane
# joss : joss
# jhabwskbwwhhahahaw : jhabwskbwwhhahahaw
# sc : sc
# ecommurz : ecommurz
# kismin : kismin
# ngedowngrade : ngedowngrade
# ngene : ngene
# japri : japri
# daapt : daapt
# nissan : nissan
# lovers : lovers
# nissannews : nissannews
# unikorn : unikorn
# mbensin : mbensin
# semak : semak
# jeplak : jeplak
# wouw : wouw
# tindas : tindas
# distributor : distributor
# kolaborator : kolaborator
# korporasi : korporasi
# asikk : asikk
# mbanking : mbanking
# repo : repo
# lantas : lantas
# kr : kr
# pad : pad
# paramaticplay : paramaticplay
# habanero : habanero
# pgsoft : pgsoft
# pecintaslot : pecintaslot
# bocoranslot : bocoranslot
# rtpslot : rtpslot
# rtpalotonline : rtpalotonline
# totogelap : totogelap
# prediksisydney : prediksisydney
# prediksisiangapore : prediksisiangapore
# prediksihongkong : prediksihongkong
# bocorantogel : bocorantogel
# bandardarat : bandardarat
# detikers : detikers
# pollingnya : pollingnya
# zonabanten : zonabanten
# ceekkk : ceekkk
# sakdurunge : sakdurunge
# papaloren : papaloren
# apani : apani
# privilege : privilege
# mapping : mapping
# curiga : curiga
# taut : taut
# wta : wta
# ngelag : ngelag
# mreka : mreka
# modus : modus
# webnya : webnya
# sepertix : sepertix
# dun : dun
# gu : gu
# sarana : sarana
# supercepat : supercepat
# depisit : depisit
# etoll : etoll
# tempofoto : tempofoto
# mengg : mengg
# bandel : bandel
# cerita : cerita
# nemu : nemu
# salam : salam
# kabartrenggalek : kabartrenggalek
# trenggalek : trenggalek
# sulsel : sulsel
# sihh : sihh
# brand : brand
# dream : dream
# acu : acu
# kereta : kereta
# ourgorengan : ourgorengan
# infographic : infographic
# pingin : pingin
# paytren : paytren
# bangett : bangett
# sebagai : bagai
# investor : investor
# nihhh : nihhh
# spbg : spbg
# toko : toko
# citra : citra
# mleduq : mleduq
# bijimana : bijimana
# cobak : cobak
# elektrik : elektrik
# belisolarpakaiapilkasi : belisolarpakaiapilkasi
# belipertalitepakaiaplikasi : belipertalitepakaiaplikasi
# apilasi : apilasi
# diskriminatif : diskriminatif
# serbi : serbi
# mmc : mmc
# inisiasi : inisiasi
# efesien : efesien
# is : is
# mistake : mistake
# stres : stres
# bedua : bedua
# diajarin : diajarin
# sepuh : sepuh
# tlg : tlg
# kecam : kecam
# gasmelon : gasmelon
# aktivasi : aktivasi
# ahh : ahh
# jatuhin : jatuhin
# belu : belu
# amanah : amanah
# dang : dang
# siasat : siasat
# check : check
# be : be
# wise : wise
# bersubdi : bersubdi
# brilian : brilian
# reting : reting
# burung : burung
# tekedown : tekedown
# psnya : psnya
# ngehapus : ngehapus
# dankawankawan : dankawankawan
# sihp : sihp
# woiii : woiii
# sengaja : sengaja
# menutupi : tutup
# sblmnya : sblmnya
# motif : motif
# nonformal : nonformal
# insttal : insttal
# pack : pack
# nyh : nyh
# wahhh : wahhh
# kerenn : kerenn
# earning : earning
# melal : melal
# sih : sih
# anjirlahhhhhhh : anjirlahhhhhhh
# redeem : redeem
# kwalitas : kwalitas
# yuu : yuu
# lampang : lampang
# bertanggungjawab : bertanggungjawab
# racun : racun
# sandal : sandal
# slip : slip
# jelly : jelly
# oren : oren
# rekomendasishopee : rekomendasishopee
# racunshopee : racunshopee
# sandals : sandals
# holy : holy
# sungkan : sungkan
# lambat : lambat
# electronic : electronic
# hamba : hamba
# hesoyam : hesoyam
# updatebali : updatebali
# cashlesa : cashlesa
# tuk : tuk
# ukur : ukur
# ndang : ndang
# do : do
# po : po
# ingin : ingin
# tukuo : tukuo
# nyablon : nyablon
# banner : banner
# dipaksain : dipaksain
# rewards : rewards
# lapak : lapak
# pmnya : pmnya
# integrate : integrate
# takkira : takkira
# asuuu : asuuu
# sinulingga : sinulingga
# aryasinulingga : aryasinulingga
# rumus : rumus
# kemendagri : kemendagri
# bapeda : bapeda
# rukhp : rukhp
# sarap : sarap
# apliasi : apliasi
# ituh : ituh
# nempelinnyah : nempelinnyah
# jidat : jidat
# endonesa : endonesa
# yang : yang
# apah : apah
# apple : apple
# mola : mola
# wtp : wtp
# kemhan : kemhan
# tentaranasionalindonesia : tentaranasionalindonesia
# bouttier : bouttier
# kcon : kcon
# wkkwkw : wkkwkw
# ngopi : ngopi
# ewallet : ewallet
# partner : partner
# cod : cod
# gass : gass
# wc : wc
# bestiee : bestiee
# fenomena : fenomena
# timpang : timpang
# ngisinya : ngisinya
# truck : truck
# wawancara : wawancara
# wing : wing
# ijek : ijek
# entuk : entuk
# bukn : bukn
# perlahan : perlahan
# berpengarh : berpengarh
# terhadap : hadap
# mngisi : mngisi
# jls : jls
# mngurangi : mngurangi
# jlh : jlh
# tenaga : tenaga
# turn : turn
# siapin : siapin
# yaaakkk : yaaakkk
# paket : paket
# tambahin : tambahin
# beji : beji
# moemax : moemax
# aktor : aktor
# pahlevi : pahlevi
# pertalaite : pertalaite
# mewjibkan : mewjibkan
# tdknya : tdknya
# hukum : hukum
# pres : pres
# menjadi : jadi
# domain : domain
# chip : chip
# ghosting : ghosting
# provider : provider
# bearish : bearish
# rebound : rebound
# bambang : bambang
# nonsubsidi : nonsubsidi
# skitar : skitar
# kamsute : kamsute
# kite : kite
# ukuranya : ukuranya
# npwp : npwp
# disamain : disamain
# bzzzzzzzzz : bzzzzzzzzz
# temponasional : temponasional
# title : title
# alien : alien
# benr : benr
# best : best
# right : right
# sop : sop
# slain : slain
# ati : ati
# voila : voila
# they : they
# realizing : realizing
# their : their
# company : company
# vision : vision
# slow : slow
# sure : sure
# pelan : pelan
# cool : cool
# gala : gala
# young : young
# smakin : smakin
# nunggak : nunggak
# deb : deb
# kolektor : kolektor
# woii : woii
# betuuullll : betuuullll
# second : second
# naevis : naevis
# propinsi : propinsi
# kalimant : kalimant
# subdisi : subdisi
# lenyap : lenyap
# peran : peran
# lapis : lapis
# solarsubsidi : solarsubsidi
# masalah : masalah
# produsen : produsen
# gaspol : gaspol
# barcodenya : barcodenya
# pertanyaanya : pertanyaanya
# gie : gie
# dounload : dounload
# arabsaudi : arabsaudi
# gassskeun : gassskeun
# pedulilidungi : pedulilidungi
# arafah : arafah
# daptar : daptar
# ain : ain
# kahh : kahh
# palai : palai
# haru : haru
# worldhealthorganization : worldhealthorganization
# infolayananmasyarakat : infolayananmasyarakat
# manis : manis
# pundi : pundi
# hadeh : hadeh
# trmsuk : trmsuk
# terang : terang
# konter : konter
# pindai : pindai
# kurleb : kurleb
# dpn : dpn
# nyungsep : nyungsep
# wksksk : wksksk
# wjb : wjb
# kdraan : kdraan
# dscan : dscan
# trdftr : trdftr
# baru : baru
# spya : spya
# prktis : prktis
# brcodenya : brcodenya
# bgini : bgini
# ngntri : ngntri
# aplg : aplg
# bgnian : bgnian
# kruwtn : kruwtn
# sgra : sgra
# brllu : brllu
# potret : potret
# krl : krl
# scooter : scooter
# dewasa : dewasa
# skuter : skuter
# alloy : alloy
# maks : maks
# kgs : kgs
# collabonationtour : collabonationtour
# agnezmob : agnezmob
# Cumamiscall : cumamiscall
# geprek : geprek
# morning : morning
# viar : viar
# karya : karya
# bit : bit
# road : road
# onepiece : onepiece
# san : san
# declan : declan
# slide : slide
# kulit : kulit
# empuk : empuk
# stylish : stylish
# alamaak : alamaak
# laknatulloh : laknatulloh
# bukannya : bukan
# pedulipejabatzalim : pedulipejabatzalim
# fitnah : fitnah
# dajjal : dajjal
# hbs : hbs
# anies : anies
# holywingslecehkanislam : holywingslecehkanislam
# bapakpolitikidentitas : bapakpolitikidentitas
# tutuptempatmaksiat : tutuptempatmaksiat
# tka : tka
# china : china
# arab : arab
# saudi : saudi
# logik : logik
# nyobian : nyobian
# cantum : cantum
# pami : pami
# tos : tos
# bade : bade
# kumahakeun : kumahakeun
# pamarentah : pamarentah
# kantun : kantun
# damel : damel
# pulang : pulang
# mudik : mudik
# ucapin : ucapin
# kado : kado
# neng : neng
# fine : fine
# bulan : bulan
# wawas : wawas
# sempit : sempit
# pensin : pensin
# gabolrh : gabolrh
# dzulhijjjah : dzulhijjjah
# dakwah : dakwah
# islam : islam
# dont : dont
# wait : wait
# thank : thank
# wayv : wayv
# instagramdown : instagramdown
# ahayy : ahayy
# wkwkk : wkwkk
# dapt : dapt
# order : order
# waini : waini
# outoftopic : outoftopic
# mahzab : mahzab
# collecting : collecting
# muka : muka
# spam : spam
# biadab : biadab
# bolak : bolak
# lawas : lawas
# bpbd : bpbd
# angin : angin
# kencang : kencang
# sak : sak
# ambul : ambul
# jenazah : jenazah
# pegawainegerisipil : pegawainegerisipil
# cair : cair
# wallahu : wallahu
# begituu : begituu
# dansebagainya : dansebagainya
# hipokrit : hipokrit
# nyusain : nyusain
# ajah : ajah
# oohh : oohh
# kencan : kencan
# jemput : jemput
# kep : kep
# tingkat : tingkat
# iflix : iflix
# vsco : vsco
# vpn : vpn
# giselle : giselle
# cha : cha
# minho : minho
# sehingga : sehingga
# apliikasi : apliikasi
# ditambahh : ditambahh
# parkir : parkir
# sunnah : sunnah
# ngerasa : ngerasa
# terseb : terseb
# institut : institut
# ridwan : ridwan
# efendi : efendi
# radiasi : radiasi
# diw : diw
# selep : selep
# gabah : gabah
# nggawe : nggawe
# aihh : aihh
# guaaa : guaaa
# njirr : njirr
# nahh : nahh
# his : his
# ngeunduh : ngeunduh
# segaptek : segaptek
# kunyuk : kunyuk
# ituuuu : ituuuu
# nyebelin : nyebelin
# juru : juru
# membrantas : membrantas
# sara : sara
# bandarwalet : bandarwalet
# rtp : rtp
# rtpbandarwalet : rtpbandarwalet
# rtphariini : rtphariini
# dsini : dsini
# dimanfaatkn : dimanfaatkn
# scanner : scanner
# scra : scra
# relatime : relatime
# jembatan : jembatan
# visual : visual
# trkontrol : trkontrol
# sayatidaktahu : sayatidaktahu
# many : many
# stations : stations
# malang : malang
# folks : folks
# apal : apal
# lempar : lempar
# gaduh : gaduh
# diem : diem
# periode : periode
# agnezmoboymagnet : agnezmoboymagnet
# sanji : sanji
# gigi : gigi
# kisssi : kisssi
# bnrin : bnrin
# bpkku : bpkku
# sndri : sndri
# obrol : obrol
# dllnya : dllnya
# apalg : apalg
# keparnoan : keparnoan
# brng : brng
# klrg : klrg
# omng : omng
# tarok : tarok
# ngegas : ngegas
# tilulit : tilulit
# angkotnya : angkotnya
# pampang : pampang
# lipi : lipi
# yuyu : yuyu
# numpang : numpang
# registra : registra
# pelangi : pelangi
# bri : bri
# bsi : bsi
# livechat : livechat
# msmarvel : msmarvel
# chelsea : chelsea
# nato : nato
# yaaah : yaaah
# untun : untun
# untk : untk
# pnya : pnya
# penghisap : penghisap
# darah : darah
# care : care
# persik : persik
# beritabaru : beritabaru
# beritabaruco : beritabaruco
# seingetku : seingetku
# pernah : pernah
# disounding : disounding
# programna : programna
# adaptasi : adaptasi
# niscaya : niscaya
# melek : melek
# ngelacak : ngelacak
# karet : karet
# licin : licin
# bli : bli
# pertanax : pertanax
# jatimberitabaruco : jatimberitabaruco
# subscribe : subscribe
# rbu : rbu
# wkowkwokwow : wkowkwokwow
# klasik : klasik
# rambah : rambah
# net : net
# posesif : posesif
# ngehujat : ngehujat
# ngajak : ngajak
# dibayarin : dibayarin
# btsintheseom : btsintheseom
# also : also
# baka : baka
# bohong : bohong
# layanin : layanin
# topnews : topnews
# trans : trans
# jaditau : jaditau
# sungsang : sungsang
# drunn : drunn
# battery : battery
# djancookkk : djancookkk
# dirut : dirut
# pendaftaraan : pendaftaraan
# sulut : sulut
# pg : pg
# tunas : tunas
# tamankanak-kanak : tamankanak-kanak
# sd : sd
# murung : murung
# pudak : pudak
# sman : sman
# tanjung : tanjung
# produksi : produksi
# maskapai : maskapai
# terbang : terbang
# pelita : pelita
# stafsus : stafsus
# brigh : brigh
# downlod : downlod
# dinyalain : dinyalain
# ksp : ksp
# komut : komut
# salar : salar
# mrintah : mrintah
# nyemir : nyemir
# lidahlu : lidahlu
# narapidana : narapidana
# member : member
# perkara : perkara
# kilafah : kilafah
# erick : erick
# thohir : thohir
# gening : gening
# bogor : bogor
# usung : usung
# kerjasama : kerjasama
# brad : brad
# jones : jones
# racing : racing
# supercars : supercars
# indigenous : indigenous
# round : round
# far : far
# gaenak : gaenak
# hii : hii
# bidji : bidji
# sistimnya : sistimnya
# udahan : udahan
# gamuat : gamuat
# ep : ep
# bor : bor
# sumur : sumur
# kursi : kursi
# konsekwensi : konsekwensi
# tanam : tanam
# laris : laris
# hierarki : hierarki
# nyebrang : nyebrang
# campur : campur
# kuras : kuras
# udahlah : udahlah
# reimburse : reimburse
# nota : nota
# malu : malu
# aplikadi : aplikadi
# injek : injek
# nuwun : nuwun
# sewu : sewu
# gim : gim
# driver : driver
# ojol : ojol
# tinjau : tinjau
# pelosok : pelosok
# lulus : lulus
# ngeuh : ngeuh
# pribumi : pribumi
# serasa : serasa
# tamu : tamu
# jangkau : jangkau
# aktifin : aktifin
# meledsk : meledsk
# tqmbal : tqmbal
# buduh : buduh
# udab : udab
# ngerokok : ngerokok
# ciri : ciri
# apakabar : apakabar
# caci : caci
# maki : maki
# rutin : rutin
# klai : klai
# siih : siih
# gasih : gasih
# nyeker : nyeker
# stok : stok
# oalaahhhhhh : oalaahhhhhh
# unnie : unnie
# karung : karung
# dandan : dandan
# cantip : cantip
# wkwkwkkwkw : wkwkwkkwkw
# ramah : ramah
# tamah : tamah
# gemesinnn : gemesinnn
# cewek : cewek
# misterius : misterius
# fire : fire
# triangle : triangle
# basic : basic
# knowledge : knowledge
# safety : safety
# training : training
# maritime : maritime
# edustaff : edustaff
# universitas : universitas
# semangatt : semangatt
# gabutuh : gabutuh
# dijakarta : dijakarta
# otaknyah : otaknyah
# ngurusnya : ngurusnya
# alumni : alumni
# gatal : gatal
# president : president
# modiar : modiar
# kapolresta : kapolresta
# audensi : audensi
# action : action
# counter : counter
# measure : measure
# emisi : emisi
# angktan : angktan
# klopun : klopun
# case : case
# policy : policy
# woi : woi
# oprator : oprator
# wakakakakkkk : wakakakakkkk
# coustumer : coustumer
# kadrung : kadrung
# kelennnn : kelennnn
# naung : naung
# yuuk : yuuk
# ketawa : ketawa
# beleng : beleng
# afk : afk
# pertalait : pertalait
# sutera : sutera
# ngebet : ngebet
# dapetin : dapetin
# ribed : ribed
# ginih : ginih
# duwit : duwit
# bukadraftrkuhp : bukadraftrkuhp
# mingkin : mingkin
# danta : danta
# apahan : apahan
# isinyah : isinyah
# cons : cons
# tukang : tukang
# tumbang : tumbang
# dulur : dulur
# personil : personil
# that : that
# if : if
# done : done
# with : with
# supervision : supervision
# diladenin : diladenin
# yee : yee
# jember : jember
# wekekekekek : wekekekekek
# rjbt : rjbt
# kepung : kepung
# ugal : ugal
# ugalan : ugalan
# naikin : naikin
# jidad : jidad
# bola : bola
# jaw : jaw
# len : len
# reog : reog
# jenderal : jenderal
# atr : atr
# penagkapan : penagkapan
# pensiun : pensiun
# muhamad : muhamad
# husen : husen
# dijafikan : dijafikan
# pagar : pagar
# eksekusi : eksekusi
# oranf : oranf
# nini : nini
# track : track
# analisa : analisa
# publik : publik
# wkw : wkw
# transaskinya : transaskinya
# langsung,umum,bebas,danrahasia : langsung umum bebas danrahasia
# satsetsatset : satsetsatset
# oktannya : oktannya
# ikhtiar : ikhtiar
# ane : ane
# pol : pol
# ngakalin : ngakalin
# modifikasi : modifikasi
# kepul : kepul
# tangkap : tangkap
# lawat : lawat
# ngetrack : ngetrack
# aset : aset
# sdm : sdm
# periksa : periksa
# angota : angota
# kodim : kodim
# beton : beton
# random : random
# gbr : gbr
# hapenya : hapenya
# esia : esia
# hidayah : hidayah
# lip : lip
# singapore : singapore
# mat : mat
# tuntut : tuntut
# logis : logis
# negera : negera
# penggal : penggal
# kebaya : kebaya
# meng : meng
# menggunkana : menggunkana
# girlfriend : girlfriend
# gaduwe : gaduwe
# opo : opo
# jendral : jendral
# klim : klim
# irjen : irjen
# dep : dep
# dagri : dagri
# gubernur : gubernur
# trillun : trillun
# trilliun : trilliun
# malaysia : malaysia
# mur : mur
# pantesan : pantesan
# beak : beak
# korupsieun : korupsieun
# hayang : hayang
# neang : neang
# tinu : tinu
# nanaon : nanaon
# cik : cik
# mun : mun
# moal : moal
# koclak : koclak
# nenggak : nenggak
# ajegile : ajegile
# companynya : companynya
# profit : profit
# pesat : pesat
# storytelling : storytelling
# blabla : blabla
# nyiyirin : nyiyirin
# jawb : jawb
# kertas : kertas
# enjoy : enjoy
# inspeksimendadak : inspeksimendadak
# terna : terna
# ngembangin : ngembangin
# pertashop : pertashop
# ngahajar : ngahajar
# kongkalikong : kongkalikong
# haters : haters
# cuit : cuit
# nitip : nitip
# sultan : sultan
# belikan : belikan
# mentok : mentok
# cma : cma
# tuiteran : tuiteran
# browser : browser
# begimane : begimane
# ditangerang : ditangerang
# ye : ye
# ibu : ibu
# kumpul-kumpul : kumpul
# juatru : juatru
# singkir : singkir
# hy : hy
# pencil : pencil
# hangat : hangat
# ciumin : ciumin
# gelud : gelud
# bahasin : bahasin
# jelata : jelata
# ahhhh : ahhhh
# jilat : jilat
# liur : liur
# biasapan : biasapan
# lamun : lamun
# maksudna : maksudna
# anu : anu
# sigana : sigana
# soalna : soalna
# singkron : singkron
# luamayan : luamayan
# adminna : adminna
# gagap : gagap
# prtimbangan : prtimbangan
# rakyatmenuntutkeadilan : rakyatmenuntutkeadilan
# puang : puang
# margonda : margonda
# kirain : kirain
# diwajibin : diwajibin
# signalnya : signalnya
# rachman : rachman
# bei : bei
# lenggang : lenggang
# polyponic : polyponic
# opung : opung
# diapus : diapus
# inj : inj
# boot : boot
# hormat : hormat
# didu : didu
# man : man
# diarahin : diarahin
# berapaa : berapaa
# megang : megang
# semprot : semprot
# tsay : tsay
# feature : feature
# meanwhile : meanwhile
# yekan : yekan
# mentah : mentah
# tumpah : tumpah
# pantai : pantai
# dermaga : dermaga
# cilacap : cilacap
# dpchnsihimpunannelayanseluruhindonesia : dpchnsihimpunannelayanseluruhindonesia
# headlinenews : headlinenews
# kelurahantambakreja : kelurahantambakreja
# kilangminyak : kilangminyak
# nelayancilacap : nelayancilacap
# pantaicilacap : pantaicilacap
# perahupenyeberangan : perahupenyeberangan
# karyawannya : karyawannya
# istirahat : istirahat
# jugaaa : jugaaa
# box : box
# ter : ter
# gugat : gugat
# iii : iii
# pemilil : pemilil
# haa : haa
# kontrak : kontrak
# had : had
# gaya : gaya
# aus : aus
# petamax : petamax
# tankki : tankki
# apaaa : apaaa
# punyaa : punyaa
# rasain : rasain
# sentris : sentris
# berselfie : berselfie
# ria : ria
# rezimulator : rezimulator
# ...
# bankrupt : bankrupt
# then : then
# stupid : stupid
# policies : policies
# lower : lower
# class : class
# imagine : imagine
# evil : evil
# budaya : budaya
# lembar : lembar
# milih : milih
# rian : rian
# posted : posted
# blog : blog
# oyo : oyo
# primer : primer
# jepang : jepang
# nowonair : nowonair
# nkaja : nkaja
# dsbg : dsbg
# amsyong : amsyong
# aba : aba
# superhero : superhero
# tebak : tebak
# ngerepotin : ngerepotin
# les : les
# pengertiam : pengertiam
# wkkwk : wkkwk
# duaarrrr : duaarrrr
# laen : laen
# tenyata : tenyata
# lonjong : lonjong
# cil : cil
# inews : inews
# lhaa : lhaa
# silang : silang
# wijayapura : wijayapura
# nusakambangan : nusakambangan
# nyambung : nyambung
# demograsi : demograsi
# dipom : dipom
# ngebenerin : ngebenerin
# hahahahahaha : hahahahahaha
# ngestate : ngestate
# statement : statement
# sebelmnya : sebelmnya
# tapiiiiiiiii : tapiiiiiiiii
# iktan : iktan
# lau : lau
# eligible : eligible
# makane : makane
# nana : nana
# ninu : ninu
# ealah : ealah
# empane : empane
# maca : maca
# krena : krena
# aflikasi : aflikasi
# aflikasinya : aflikasinya
# lusa : lusa
# batak : batak
# yntkts : yntkts
# persijaday : persijaday
# sso : sso
# pattern : pattern
# scarf : scarf
# akane : akane
# fajri : fajri
# kesitu : kesitu
# reporter : reporter
# dinsos : dinsos
# pejabut : pejabut
# yeee : yeee
# jaka : jaka
# sembung : sembung
# traffic : traffic
# trafficnya : trafficnya
# bledug : bledug
# jenius : jenius
# clue : clue
# dijabarin : dijabarin
# programer : programer
# akunting : akunting
# tidakacuh : tidakacuh
# planning : planning
# lewatin : lewatin
# diurusin : diurusin
# efek : efek
# selaluu : selaluu
# tuan : tuan
# sensus : sensus
# tambah : tambah
# bod : bod
# kebijakanngaco : kebijakanngaco
# kaos : kaos
# rib : rib
# qontol : qontol
# dita : dita
# masuj : masuj
# spbum : spbum
# yuridis : yuridis
# cocot : cocot
# resin : resin
# framingnya : framingnya
# yakaannn : yakaannn
# akuisisi : akuisisi
# absolut : absolut
# bbk : bbk
# ketitiknews : ketitiknews
# beritaringkas : beritaringkas
# hematwaktubacaberita : hematwaktubacaberita
# beritasingkat : beritasingkat
# hnsi : hnsi
# pencemaranminyakmentah : pencemaranminyakmentah
# asww : asww
# mengugat : mengugat
# duku : duku
# dibolehin : dibolehin
# electrum : electrum
# gogoro : gogoro
# gesits : gesits
# fajar : fajar
# sampa : sampa
# makinamanmakincerdas : makinamanmakincerdas
# deuuuhh : deuuuhh
# lewak : lewak
# sidoarjo : sidoarjo
# nosel : nosel
# mksdnya : mksdnya
# sumbang : sumbang
# yatim : yatim
# piatu : piatu
# dhuafa : dhuafa
# seri : seri
# sedan : sedan
# gedong : gedong
# pertelite : pertelite
# perdu : perdu
# jendala : jendala
# kaca : kaca
# atw : atw
# elektromagnetik : elektromagnetik
# megaelektron : megaelektron
# volt : volt
# peta : peta
# elektronvolt : elektronvolt
# pdi : pdi
# pomp : pomp
# watir : watir
# hayangna : hayangna
# nepi : nepi
# kitu : kitu
# smkin : smkin
# dpersulit : dpersulit
# hem : hem
# faktaunik : faktaunik
# infounik : infounik
# agridaily : agridaily
# apus : apus
# hang : hang
# trafic : trafic
# muter : muter
# sbnrnya : sbnrnya
# perharin : perharin
# ngaco : ngaco
# costumer : costumer
# depot : depot
# gblh : gblh
# beritasatu : beritasatu
# heula : heula
# kadar : kadar
# smashnews : smashnews
# beritaterbaru : beritaterbaru
# beritaterupdate : beritaterupdate
# kabarterbaru : kabarterbaru
# bismilahirrohmanirohim : bismilahirrohmanirohim
# aamin : aamin
# miskom : miskom
# alhasil : alhasil
# hamil : hamil
# ninggalin : ninggalin
# bcs : bcs
# panungtungan : panungtungan
# oyi : oyi
# pakqi : pakqi
# dbikin : dbikin
# susaha : susaha
# downloads : downloads
# trss : trss
# thr : thr
# bogum : bogum
# finally : finally
# got : got
# answer : answer
# sindir : sindir
# awi : awi
# mob : mob
# validnews : validnews
# cpt : cpt
# balap : balap
# doyok : doyok
# noban : noban
# gob : gob
# gayalu : gayalu
# negor : negor
# diketawain : diketawain
# abg : abg
# sakittt : sakittt
# warming : warming
# panutan : panutan
# bobol : bobol
# dganmu : dganmu
# bula : bula
# gtvnews : gtvnews
# bahanbakar : bahanbakar
# ciamik : ciamik
# discuss : discuss
# holywing : holywing
# eksport : eksport
# ituhhhh : ituhhhh
# tuntassss : tuntassss
# driyorejo : driyorejo
# siihh : siihh
# datamobil : datamobil
# jikaa : jikaa
# cekek : cekek
# fresher : fresher
# untuk : untuk
# siar : siar
# telfonan : telfonan
# airplane : airplane
# search : search
# gsuka : gsuka
# mayah : mayah
# pick : pick
# agi : agi
# bankarthagrahainternasional : bankarthagrahainternasional
# agibybankarthagrahainternasional : agibybankarthagrahainternasional
# sponsor : sponsor
# mewekk : mewekk
# beritacilac : beritacilac
# atik : atik
# pass : pass
# jorji : jorji
# privacy : privacy
# intr : intr
# middle : middle
# hightlevel : hightlevel
# transprancy : transprancy
# phising : phising
# publict : publict
# read : read
# terjal : terjal
# transparan : transparan
# skuy : skuy
# responsif : responsif
# linding : linding
# leduk : leduk
# petalite : petalite
# nsebenernya : nsebenernya
# elek : elek
# bergese : bergese
# cebonk : cebonk
# paradoks : paradoks
# stangmu : stangmu
# templekki : templekki
# seko : seko
# telusur : telusur
# tumpa : tumpa
# injeksi : injeksi
# nmengharuskan : nmengharuskan
# oktan : oktan
# nwkwkwk : nwkwkwk
# nscannya : nscannya
# nbeli : nbeli
# nalso : nalso
# dibay : dibay
# nmasuk : nmasuk
# gedung : gedung
# siape : siape
# lutut : lutut
# mnghsilkan : mnghsilkan
# sense : sense
# belongingnya : belongingnya
# njuga : njuga
# nmungkin : nmungkin
# nantrian : nantrian
# gaming : gaming
# nsaya : nsaya
# timeout : timeout
# pesisir : pesisir
# rebut : rebut
# tump : tump
# punchline : punchline
# rumpi : rumpi
# nkata : nkata
# nqrcode : nqrcode
# didonlot : didonlot
# npasang : npasang
# kurungin : kurungin
# ntuhkan : ntuhkan
# kam : kam
# hub : hub
# emangnye : emangnye
# udeh : udeh
# yaiyasi : yaiyasi
# gaksi : gaksi
# sol : sol
# jel : jel
# kaki : kaki
# nhiiiiiikkkkssss : nhiiiiiikkkkssss
# nbetul : nbetul
# ntp : ntp
# buahahahahqhqhaha : buahahahahqhqhaha
# rambu : rambu
# negar : negar
# propin : propin
# kukaha : kukaha
# manehteh : manehteh
# ongkoh : ongkoh
# ker : ker
# jol : jol
# gablag : gablag
# awet : awet
# penjuala : penjuala
# film : film
# tremors : tremors
# ntahap : ntahap
# nsiapkan : nsiapkan
# nbuka : nbuka
# polri : polri
# prematur : prematur
# tabrak : tabrak
# konsumenny : konsumenny
# nape : nape
# nspbu : nspbu
# duaarrr : duaarrr
# npdhal : npdhal
# bgitu : bgitu
# ml : ml
# kenalin : kenalin
# lang : lang
# inilo : inilo
# merek : merek
# inimah : inimah
# hdehhh : hdehhh
# looo : looo
# perusahaa : perusahaa
# biasane : biasane
# bibi : bibi
# misuh : misuh
# sebage : sebage
# nasi : nasi
# norang : norang
# psi : psi
# nlihat : nlihat
# nmulai : nmulai
# naplikasi : naplikasi
# bersubs : bersubs
# tukune : tukune
# mbayar : mbayar
# nkok : nkok
# nopo : nopo
# untunge : untunge
# akeh : akeh
# hanaya : hanaya
# moncong : moncong
# porno : porno
# dito : dito
# deteksi : deteksi
# nnah : nnah
# penu : penu
# penug : penug
# jubirnya : jubirnya
# nsemoga : nsemoga
# penuga : penuga
# penugasa : penugasa
# nesar : nesar
# mengikutsertakan : mengikutsertakan
# ndro : ndro
# slogan : slogan
# isoh : isoh
# nsieun : nsieun
# njangan : njangan
# nmenyimpan : nmenyimpan
# ningatlah : ningatlah
# nbisa : nbisa
# pecak : pecak
# ch : ch
# youtubenya : youtubenya
# nmending : nmending
# npt : npt
# glory : glory
# ngenesnya : ngenesnya
# nsetiap : nsetiap
# bubur : bubur
# ayam : ayam
# kihat : kihat
# am : am
# nharusnya : nharusnya
# pjg : pjg
# mnympaikn : mnympaikn
# pmlik : pmlik
# asam : asam
# nempelny : nempelny
# tangkal : tangkal
# nbismillah : nbismillah
# tersesat : sesat
# nisi : nisi
# fulltenk : fulltenk
# nagh : nagh
# nberarti : nberarti
# hhhhh : hhhhh
# edcnya : edcnya
# penyelewenga : penyelewenga
# kuwi : kuwi
# naku : naku
# mbelani : mbelani
# robot : robot
# penggangguran : penggangguran
# nbapak : nbapak
# berncana : berncana
# pembe : pembe
# ngatain : ngatain
# menejer : menejer
# kemensul : kemensul
# esmelon : esmelon
# nkategori : nkategori
# nyentuh : nyentuh
# rusa : rusa
# pernahh : pernahh
# ginii : ginii
# ndosen : ndosen
# sera : sera
# ajeng : ajeng
# maaah : maaah
# avtur : avtur
# nada : nada
# nbukankah : nbukankah
# jkw : jkw
# nperaturan : nperaturan
# rijik : rijik
# satire : satire
# ampuh : ampuh
# ala : ala
# lanka : lanka
# token : token
# hashtag : hashtag
# luckyfriday : luckyfriday
# fanpage : fanpage
# mengon : mengon
# mantaaaappps : mantaaaappps
# nlalu : nlalu
# udang : udang
# sima : sima
# ketidakjelasan : ketidakjelasan
# nsebelum : nsebelum
# nsetakut : nsetakut
# datany : datany
# infras : infras
# galakin : galakin
# keribetannya : keribetannya
# ngantr : ngantr
# urut : urut
# handal : handal
# brrti : brrti
# mantaaap : mantaaap
# falam : falam
# konferensi : konferensi
# pers : pers
# kepolisiandaerah : kepolisiandaerah
# pidana : pidana
# shrnya : shrnya
# terapkn : terapkn
# kesatria : kesatria
# convenience : convenience
# foodcourt : foodcourt
# ndan : ndan
# nsementara : nsementara
# daer : daer
# nmakasih : nmakasih
# rujuk : rujuk
# thankyou : thankyou
# nbayar : nbayar
# ntetap : ntetap
# nknp : nknp
# nsesuatu : nsesuatu
# nlah : nlah
# ncuman : ncuman
# zalim : zalim
# bikinruwet : bikinruwet
# nhallo : nhallo
# nbgmn : nbgmn
# rate : rate
# sald : sald
# bestieku : bestieku
# dumai : dumai
# memperti : memperti
# targ : targ
# leperi : leperi
# ceode : ceode
# stickernya : stickernya
# dojawab : dojawab
# mledug : mledug
# kabarotocom : kabarotocom
# aplikasnya : aplikasnya
# maintena : maintena
# ygs : ygs
# jbkp : jbkp
# bny : bny
# handpone : handpone
# sibangsattt : sibangsattt
# katany : katany
# nhttps : nhttps
# provin : provin
# formalitas : formalitas
# syahwatny : syahwatny
# klasifikasi : klasifikasi
# sasa : sasa
# improve : improve
# perahatikan : perahatikan
# pasok : pasok
# ohya : ohya
# briefing : briefing
# nhoax : nhoax
# dahal : dahal
# jufa : jufa
# gunain : gunain
# delete : delete
# njing : njing
# parahh : parahh
# sekarat : sekarat
# ncari : ncari
# dprlayakdireformasitotal : dprlayakdireformasitotal
# rakyatsudahmuak : rakyatsudahmuak
# tele : tele
# nudh : nudh
# goodbye : goodbye
# seyogyanya : seyogyanya
# argumentasi : argumentasi
# ncoba : ncoba
# nterus : nterus
# bedaaaaa : bedaaaaa
# bedaaaaaaa : bedaaaaaaa
# bedaaaa : bedaaaa
# laaaaah : laaaaah
# ngendapin : ngendapin
# gengs : gengs
# menggunak : menggunak
# mutual : mutual
# februari : februari
# darat : darat
# nmikir : nmikir
# menggu : menggu
# tanggu : tanggu
# rakya : rakya
# nmau : nmau
# masya : masya
# ntk : ntk
# nsd : nsd
# nsmp : nsmp
# un : un
# nanak : nanak
# nl : nl
# sepat : sepat
# nitu : nitu
# ncc : ncc
# lulu : lulu
# nkalau : nkalau
# nmisalnya : nmisalnya
# ncontoh : ncontoh
# penyalu : penyalu
# nsudah : nsudah
# ns : ns
# nnanti : nnanti
# har : har
# norg : norg
# terd : terd
# nbiar : nbiar
# nyuuk : nyuuk
# cu : cu
# terdaf : terdaf
# ser : ser
# nkatanya : nkatanya
# awa : awa
# dikemba : dikemba
# napakah : napakah
# beneri : beneri
# soaln : soaln
# ket : ket
# nmas : nmas
# nudah : nudah
# kelam : kelam
# pu : pu
# mal : mal
# bahw : bahw
# nnongkrong : nnongkrong
# nindonesia : nindonesia
# ngana : ngana
# nrakyat : nrakyat
# sigan : sigan
# nribet : nribet
# ninformasi : ninformasi
# nselengkapnya : nselengkapnya
# menyusa : menyusa
# perpanjan : perpanjan
# oleh : oleh
# lin : lin
# mundu : mundu
# terutam : terutam
# berika : berika
# sua : sua
# nwajarlah : nwajarlah
# ntapi : ntapi
# apli : apli
# nyuk : nyuk
# simalak : simalak
# kur : kur
# npertalite : npertalite
# nfoto : nfoto
# sa : sa
# nkonteks : nkonteks
# key : key
# nteriak : nteriak
# tid : tid
# pela : pela
# nari : nari
# nuyuhan : nuyuhan
# miny : miny
# thi : thi
# kal : kal
# nuntung : nuntung
# npadahal : npadahal
# ula : ula
# nayo : nayo
# ndi : ndi
# nbtw : nbtw
# sukseska : sukseska
# nkami : nkami
# beg : beg
# njgn : njgn
# nberhasil : nberhasil
# finan : finan
# nbe : nbe
# nungkap : nungkap
# ntolong : ntolong
# nbang : nbang
# nmakin : nmakin
# mengund : mengund
# nperusahan : nperusahan
# nkan : nkan
# nzaman : nzaman
# njadi : njadi
# nterapkan : nterapkan
# alama : alama
# ked : ked
# seman : seman
# mot : mot
# rugika : rugika
# ped : ped
# nantri : nantri
# tete : tete
# negarany : negarany
# nmafia : nmafia
# nmasih : nmasih
# deve : deve
# {'alun': 'alun', 'al': 'al', 'kahfi': 'kahfi', 'malam': 'malam', 'semoga': 'moga', 'allah': 'allah', 'rahmat': 'rahmat', 'jalan': 'jalan', 'bakri': 'bakri', 'putin': 'putin', 'terimakasih': 'terimakasih', 'juni': 'juni', 'beli': 'beli', 'bensin': 'bensin', 'deh': 'deh', 'pakai': 'pakai', 'apk': 'apk', 'warga': 'warga', 'kota': 'kota', 'tasikmalaya': 'tasikmalaya', 'pilih': 'pilih', 'bbm': 'bbm', 'spbu': 'spbu', 'daerah': 'daerah', 'tetangga': 'tetangga', 'uji': 'uji', 'coba': 'coba', 'perta': 'perta', 'tuku': 'tuku', 'subsidi': 'subsidi', 'sing': 'sing', 'harus': 'harus', 'nganggo': 'nganggo', 'aplikasi': 'aplikasi', 'daftar': 'daftar', 'tapi': 'tapi', 'save': 'save', 'data': 'data', 'kendara': 'kendara', 'mu': 'mu', 'edit': 'edit', 'bagaimana': 'bagaimana', 'sunbsiditepat': 'sunbsiditepat', 'solusi': 'solusi', 'efektif': 'efektif', 'tekan': 'tekan', 'beban': 'beban', 'uang': 'uang', 'negara': 'negara', 'salur': 'salur', 'sasar': 'sasar', 'salah': 'salah', 'mengendalika': 'mengendalika', 'gin': 'gin', 'melulu': 'melulu', 'dahh': 'dahh', 'syarat': 'syarat', 'bahan': 'bahan', 'bakar': 'bakar', 'minyak': 'minyak', 'pertalite': 'pertalite', 'da': 'da', 'antri': 'antri', 'gara-gara': 'gara-gara', 'ternate': 'ternate', 'masuk': 'masuk', 'ujicoba': 'ujicoba', 'tolak': 'tolak', 'supir': 'supir', 'angko': 'angko', 'solar': 'solar', 'tabung': 'tabung', 'gas': 'gas', 'kg': 'kg', 'migor': 'migor', 'curah': 'curah', 'pedulilindungi': 'pedulilindungi', 'eh': 'eh', 'gilir': 'gilir', 'pem': 'pem', 'skeptis': 'skeptis', 'gtu': 'gtu', 'ah': 'ah', 'laku': 'laku', 'berma': 'berma', 'manfaat': 'manfaat', 'kendali': 'kendali', 'perintah': 'perintah', 'lpg': 'lpg', 'kocak': 'kocak', 'hmmm': 'hmmm', 'mari': 'mari', 'dukung': 'dukung', 'bijak': 'bijak', 'tugas': 'tugas', 'tali': 'tali', 'hp': 'hp', 'https': 'https', 'cap': 'cap', 'susah': 'susah', 'review': 'review', 'jelek': 'jelek', 'google': 'google', 'play': 'play', 'bersubdisi': 'bersubdisi', 'penya': 'penya', 'aman': 'aman', 'panggil': 'panggil', 'telepon': 'telepon', 'jenis': 'jenis', 'unduh': 'unduh', 'keren': 'keren', 'subs': 'subs', 'menunggu': 'tunggu', 'trend': 'trend', 'buka': 'buka', 'verifikasi': 'verifikasi', 'dic': 'dic', 'atur': 'atur', 'regulasi': 'regulasi', 'presiden': 'presiden', 'nomor': 'nomor', 'pemerintahkota': 'pemerintahkota', 'bandung': 'bandung', 'motor': 'motor', 'ken': 'ken', 'catat': 'catat', 'wilayah': 'wilayah', 'batas': 'batas', 'nyuwun': 'nyuwun', 'murah': 'murah', 'kalih': 'kalih', 'mister': 'mister', 'tertawa': 'tertawa', 'ben': 'ben', 'mboten': 'mboten', 'ngangge': 'ngangge', 'tidakjelas': 'tidakjelas', 'kasih': 'kasih', 'bintang': 'bintang', 'hapus': 'hapus', 'pagi': 'pagi', 'dengar': 'dengar', 'omel': 'omel', 'mamah': 'mamah', 'ngomel': 'ngomel', 'gara': 'gara', 'wkekekekekkekekek': 'wkekekekekkekekek', 'karywn': 'karywn', 'pertama': 'pertama', 'apa': 'apa', 'konsumen': 'konsumen', 'silah': 'silah', 'duuuaaarrrrr': 'duuuaaarrrrr', 'wajib': 'wajib', 'jual': 'jual', 'ecer': 'ecer', 'kesini': 'kesini', 'abang': 'abang', 'simpel': 'simpel', 'ri': 'ri', 'goreng': 'goreng', 'peduli': 'peduli', 'lindung': 'lindung', 'via': 'via', 'khusus': 'khusus', 'mobil': 'mobil', 'app': 'app', 'hilang': 'hilang', 'loading': 'loading', 'lemotnga': 'lemotnga', 'naudzubillah': 'naudzubillah', 'moda': 'moda', 'bayar': 'bayar', 'linkaja': 'linkaja', 'install': 'install', 'otomatis': 'otomatis', 'efisiensi': 'efisiensi', 'memori': 'memori', 'turun': 'turun', 'makan': 'makan', 'universitasindonesia': 'universitasindonesia', 'ux': 'ux', 'banget': 'banget', 'tarik': 'tarik', 'mudah': 'mudah', 'roda': 'roda', 'saja': 'saja', 'imbas': 'imbas', 'ban': 'ban', 'error': 'error', 'take': 'take', 'down': 'down', 'tidak': 'tidak', 'nyusahin': 'nyusahin', 'orang': 'orang', 'aamiin': 'aamiin', 'angkot': 'angkot', 'kalah': 'kalah', 'saing': 'saing', 'grab': 'grab', 'pulsa': 'pulsa', 'hoby': 'hoby', 'rampok': 'rampok', 'alas': 'alas', 'masyarakat': 'masyarakat', 'simak': 'simak', 'teman-teman': 'teman ...
# ------------------------
# Pandas Apply:   0%|          | 0/6738 [00:00<?, ?it/s]
# 0       [alun, al, kahfi, malam, moga, allah, rahmat, ...
# 1                         [beli, bensin, deh, pakai, apk]
# 2       [warga, kota, tasikmalaya, pilih, beli, bbm, s...
# 3       [tuku, bbm, subsidi, sing, harus, nganggo, apl...
# 4       [daftar, subsidi, tapi, save, data, kendara, m...
#                               ...
# 6733    [halah, curang, kontrol, isi, minyak, jarak, k...
# 6734    [app, tolong, bang, brando, kumandang, alias, ...
# 6735                                       [kerja, hasil]
# 6736    [lah, jaring, internet, remang, atur, aneh, ke...
# 6737    [barusan, beli, pertalite, eh, lupa, beli, per...
# Name: tweet_tokens_stemmed, Length: 6738, dtype: object

# %%
TWEET_DATA.to_csv("Text_Preprocessing.csv")

# %%
TWEET_DATA.head()
# Out:
#                                           Teksbersih  \
# 0  alun al kahfi malam moga allah rahmat jalan ba...
# 1                           beli bensin dah pake apk
# 2  warga kota tasikmalaya pilih beli bbm spbu dae...
# 3        tuku bbm subsidi sing kudu nganggo aplikasi
# 4  daftar subsidi tp ga save data kendara ny mu e...
#
#                                            translate klasifikasi  \
# 0  alun al kahfi night moga allah rahmat jalan ba...    negative
# 1                    buy gasoline already using  apk    negative
# 2  residents of the city of tasikmalaya choose bu...    negative
# 3    tuku bbm subsidized sing kudu nganggo the  appl    negative
# 4  list of subsidies but not saving data kendara ...    negative
#
#                                         tweet_tokens  \
# 0  [alun, al, kahfi, malam, moga, allah, rahmat, ...
# 1                     [beli, bensin, dah, pake, apk]
# 2  [warga, kota, tasikmalaya, pilih, beli, bbm, s...
# 3  [tuku, bbm, subsidi, sing, kudu, nganggo, apli...
# 4  [daftar, subsidi, tp, ga, save, data, kendara,...
#
#                                   tweet_tokens_fdist  \
# 0  {'alun': 1, 'al': 1, 'kahfi': 1, 'malam': 1, '...
# 1  {'beli': 1, 'bensin': 1, 'dah': 1, 'pake': 1, ...
# 2  {'warga': 1, 'kota': 1, 'tasikmalaya': 1, 'pil...
# 3  {'tuku': 1, 'bbm': 1, 'subsidi': 1, 'sing': 1,...
# 4  {'daftar': 1, 'subsidi': 1, 'tp': 1, 'ga': 2, ...
#
#                                     tweet_tokens_WSW  \
# 0  [alun, al, kahfi, malam, moga, allah, rahmat, ...
# 1                     [beli, bensin, dah, pake, apk]
# 2  [warga, kota, tasikmalaya, pilih, beli, bbm, s...
# 3  [tuku, bbm, subsidi, sing, kudu, nganggo, apli...
# 4  [daftar, subsidi, tp, save, data, kendara, mu,...
#
#                                     tweet_normalized  \
# 0  [alun, al, kahfi, malam, semoga, allah, rahmat...
# 1                    [beli, bensin, deh, pakai, apk]
# 2  [warga, kota, tasikmalaya, pilih, beli, bbm, s...
# 3  [tuku, bbm, subsidi, sing, harus, nganggo, apl...
# 4  [daftar, subsidi, tapi, save, data, kendara, m...
#
#                                 tweet_tokens_stemmed
# 0  [alun, al, kahfi, malam, moga, allah, rahmat, ...
# 1                    [beli, bensin, deh, pakai, apk]
# 2  [warga, kota, tasikmalaya, pilih, beli, bbm, s...
# 3  [tuku, bbm, subsidi, sing, harus, nganggo, apl...
# 4  [daftar, subsidi, tapi, save, data, kendara, m...

# %%
TWEET_DATA.to_excel("Text_Preprocessing_myPertamina.xlsx")
